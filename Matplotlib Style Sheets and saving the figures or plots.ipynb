# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
car_dataset=pd.read_csv(r"C:\Users\manpr\OneDrive\Desktop\Python\dataset1_inner join\car_model_dataset - Copy.csv")

# %%
car_dataset.head()
# Out:
#      ID                         Model        Date  Model Year  Rank  Score
# 0  1001  Chevrolet Pickup (Full Size)  2011-09-23        2005     1     10
# 1  1002       Ford Pickup (Full Size)  2012-08-06        2006     2     20
# 2  1003                  Toyota Camry  2013-06-20        2014     3     30
# 3  1004                 Nissan Altima  2014-05-04        2014     4     10
# 4  1005              Chevrolet Impala  2015-03-18        2004     4     20

# %%
plt.style.use('ggplot')
plt.plot(car_dataset['Rank'],car_dataset['Score'],marker='o' )
plt.xlabel('Rank')
plt.ylabel('Score')
plt.show()

# %%
plt.style.use('default')
plt.plot(car_dataset['Rank'],car_dataset['Score'],marker='o' )
plt.xlabel('Rank')
plt.ylabel('Score')
plt.show()

# %%
plt.style.use('dark_background')
plt.plot(car_dataset['Rank'],car_dataset['Score'],marker='o' )
plt.xlabel('Rank')
plt.ylabel('Score')
plt.show()

# %%
plt.style.use('grayscale')
plt.plot(car_dataset['Rank'],car_dataset['Score'],marker='o' )
plt.xlabel('Rank')
plt.ylabel('Score')
plt.show()

# %%
plt.style.use('seaborn-colorblind')
plt.plot(car_dataset['Rank'],car_dataset['Score'],marker='o' )
plt.xlabel('Rank')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# #REFERENCE:-
# Link to Matplotlib style sheets:-https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
#Saving figures

plt.style.use('bmh')
plt.plot(car_dataset['Rank'],car_dataset['Score'],marker='o' )
plt.xlabel('Rank')
plt.ylabel('Score')
plt.savefig(r"C:\Users\manpr\OneDrive\Desktop\Python\mtplotlib figures\fig2.jpg", quality=50) #quality 1 (worst), quality=95 (best)
# Out:
# <ipython-input-42-2a59b0ce1c68>:7: MatplotlibDeprecationWarning:
# The 'quality' parameter of print_jpg() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use pil_kwargs={'quality': ...} instead. If any parameter follows 'quality', they should be passed as keyword, not positionally.
#   plt.savefig(r"C:\Users\manpr\OneDrive\Desktop\Python\mtplotlib figures\fig2.jpg", quality=50) #quality 1 (worst), quality=95 (best)

# %%
plt.style.use('seaborn-bright')
plt.plot(car_dataset['Rank'],car_dataset['Score'],marker='o' )
plt.xlabel('Rank')
plt.ylabel('Score')
plt.savefig("fig2.jpg", dpi=200) #Higher the Dpi, sharper the image

# %%
plt.style.use('seaborn-dark')
plt.plot(car_dataset['Rank'],car_dataset['Score'],marker='o' )
plt.xlabel('Rank')
plt.ylabel('Score')
plt.savefig("fig3.jpg", dpi=1200)

# %%
ls
